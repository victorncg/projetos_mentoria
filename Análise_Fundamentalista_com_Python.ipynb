# %% [markdown]
# <a href="https://colab.research.google.com/github/victorncg/projetos_mentoria/blob/main/An%C3%A1lise_Fundamentalista_com_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Este arquivo foi modificado na sessão de mentoria do dia 04/04

# %% [markdown]
# # **Análise Fundamentalista com Python**

# %% [markdown]
# Este notebook foi criado como material de suporte para um novo conteúdo para as redes: "5 fontes de dados fundamentalistas que você precisa conhecer para utilizar no Python"

# %% [markdown]
# *Parte deste conteúdo foi escrito com a ajuda do ChatGPT*

# %% [markdown]
# 1. brfinance
# 2. pybacen
# 3. Alpha Vantage
# 4. Fundamentus
# 5. Finnhub

# %% [markdown]
# Aqui estão cinco bibliotecas em Python que você pode usar para obter dados fundamentalistas de ações:
#
# yfinance: Esta biblioteca permite extrair dados históricos e em tempo real de ações e outros instrumentos financeiros da Yahoo Finance. Ela fornece dados fundamentais, como demonstrações financeiras, indicadores de valuation, dados de dividendos e muito mais.
#
# Finnhub: Finnhub é uma API de dados financeiros que fornece dados em tempo real para ações, forex, criptomoedas e muito mais. É uma ótima fonte de dados fundamentalistas, fornecendo acesso a demonstrações financeiras, índices de valuation, dados de dividendos e muito mais.
#
# Alpha Vantage: Alpha Vantage é outra API de dados financeiros que fornece dados em tempo real para ações, forex, criptomoedas e muito mais. Ele fornece acesso a dados fundamentais, como demonstrações financeiras, índices de valuation, dados de dividendos e muito mais.
#
# Quandl: Quandl é uma plataforma de dados financeiros que oferece acesso a uma grande variedade de conjuntos de dados financeiros. Ele fornece acesso a dados fundamentais, como demonstrações financeiras, índices de valuation, dados de dividendos e muito mais.
#
# pandas-datareader: pandas-datareader é uma biblioteca que permite extrair dados de várias fontes financeiras, incluindo Yahoo Finance, Google Finance e muitos outros. Ele permite acessar dados fundamentais, como demonstrações financeiras, índices de valuation, dados de dividendos e muito mais.

# %% [markdown]
# # 1. brfinancemm

# %%
# !pip install brfinance
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 22.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.2/114.2 KB 1.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 264.6/264.6 KB 14.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.8/158.8 KB 9.5 MB/s eta 0:00:00
# ...

# %%
from brfinance import CVMAsyncBackend
import pandas as pd
from datetime import datetime, date


cvm_httpclient = CVMAsyncBackend()

# Dict de códigos CVM para todas as empresas
cvm_codes = cvm_httpclient.get_cvm_codes()
print(cvm_codes)
# Out:
# {'025224': '2W ECOBANK S.A. (REGISTRO ATIVO)', '917581': '2W ENERGIA S.A. (REGISTRO ATIVO)', '021954': '3A COMPANHIA SECURITIZADORA (REGISTRO CANCELADO)', '050504': '3M COMPANY (REGISTRO ATIVO)', '025291': '3R PETROLEUM ÓLEO E GÁS S.A (REGISTRO ATIVO)', '908830': '3Z REALTY DESENVOLVIMENTO IMOBILIARIO S/A (REGISTRO ATIVO)', '016330': 'EM LIQUIDAÇÃO EXTRAJUDICIAL (REGISTRO ATIVO)', '016284': '524 PARTICIPACOES S.A. (REGISTRO ATIVO)', '016349': '525 PARTICIPAÇOES SA (REGISTRO CANCELADO)', '091154': 'RIO PARANA ENERGIA S/A (INATIVA) (REGISTRO CANCELADO)', '904110': 'A  GERADORA  ALUGUEL DE MAQUINAS S.A. (REGISTRO ATIVO)', '901082': 'A BODYTECH PARTICIPACOES S.A. (REGISTRO ATIVO)', '917521': 'A. ANGELONI & CIA LTDA (REGISTRO ATIVO)', '016802': 'A.P. PARTICIPAÇOES SA (REGISTRO CANCELADO)', '910141': 'AB CONCESSOES S.A. (REGISTRO ATIVO)', '900043': 'ABA PORTO PARTICIPACOES S/A (REGISTRO ATIVO)', '900068': 'ABAPORU PARTICIPACOES S/A (REGISTRO ATIVO)', '056464': 'ABB LTD (REGISTRO ATIVO)', '
# ...

# %%
# Dict de todas as categorias de busca disponíveis (Fato relevante, DFP, ITR, etc.)
categories = cvm_httpclient.get_consulta_externa_cvm_categories()
print(categories)
# Out:
# {'EST_-1': 'TODOS os Documentos Estruturados', 'EST_3': 'ITR - Informações Trimestrais', 'EST_2': 'FRE - Formulário de Referência', 'EST_11': 'Informe do Código de Governança', 'EST_1': 'FCA - Formulário Cadastral', 'EST_4': 'DFP - Demonstrações Financeiras Padronizadas', 'EST_6': 'Informe Trimestral de Securitizadora', 'EST_13': 'IAN - Informações Anuais', 'IPE_-1_-1_-1': 'TODOS os Documentos com Informações Eventuais', 'IPE_44_-1_-1': 'Acordo de Acionistas|TODOS|   TODAS', 'IPE_1_-1_-1': 'Assembleia|TODOS|   TODAS', 'IPE_1_-1_4': 'Assembleia|TODOS|   Ata', 'IPE_1_-1_54': 'Assembleia|TODOS|   Boletim de voto a distância', 'IPE_1_-1_28': 'Assembleia|TODOS|   Edital de Convocação', 'IPE_1_-1_61': 'Assembleia|TODOS|   Instrução de voto', 'IPE_1_-1_6': 'Assembleia|TODOS|   Justificação de Incorporação, Cisão ou Fusão', 'IPE_1_-1_44': 'Assembleia|TODOS|   Manual para participação', 'IPE_1_-1_52': 'Assembleia|TODOS|   Mapa consolidado de voto a distância', 'IPE_1_-1_51': 'Assembleia|TODOS
# ...

# %%
# Realizando busca por Empresa
start_date = date(2020, 1, 1)
end_dt = date.today()
cvm_codes_list = ['21610'] # B3
category = ["EST_4", "EST_3", "IPE_4_-1_-1"] # Códigos de categoria para DFP, ITR e fatos relevantes
last_ref_date = False # Se "True" retorna apenas o último report no intervalo de datas

# %%
# Busca
search_result = cvm_httpclient.get_consulta_externa_cvm_results(
    cod_cvm=cvm_codes_list,
    start_date=start_date,
    end_date=end_dt,
    last_ref_date=last_ref_date,
    category=category
    )
# Out:
# /usr/local/lib/python3.9/dist-packages/brfinance/responses.py:78: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   response_df = response_df.append(search_results_df)

# %%
display(search_result)
# Out:
#    cod_cvm                          empresa  \
# 33  021610  B3 S.A. - BRASIL, BOLSA, BALCÃO
# 34  021610  B3 S.A. - BRASIL, BOLSA, BALCÃO
# 32  021610  B3 S.A. - BRASIL, BOLSA, BALCÃO
# 31  021610  B3 S.A. - BRASIL, BOLSA, BALCÃO
# 35  021610  B3 S.A. - BRASIL, BOLSA, BALCÃO
# 30  021610  B3 S.A. - BRASIL, BOLSA, BALCÃO
# 36  021610  B3 S.A. - BRASIL, BOLSA, BALCÃO
# 29  021610  B3 S.A. - BRASIL, BOLSA, BALCÃO
# 28  021610  B3 S.A. - BRASIL, BOLSA, BALCÃO
# 27  021610  B3 S.A. - BRASIL, BOLSA, BALCÃO
# 37  021610  B3 S.A. - BRASIL, BOLSA, BALCÃO
# 26  021610  B3 S.A. - BRASIL, BOLSA, BALCÃO
# 38  021610  B3 S.A. - BRASIL, BOLSA, BALCÃO
# 25  021610  B3 S.A. - BRASIL, BOLSA, BALCÃO
# 24  021610  B3 S.A. - BRASIL, BOLSA, BALCÃO
# 23  021610  B3 S.A. - BRASIL, BOLSA, BALCÃO
# 39  021610  B3 S.A. - BRASIL, BOLSA, BALCÃO
# 22  021610  B3 S.A. - BRASIL, BOLSA, BALCÃO
# 21  021610  B3 S.A. - BRASIL, BOLSA, BALCÃO
# 20  021610  B3 S.A. - BRASIL, BOLSA, BALCÃO
# ...

# %%
# Obter demonstrativos

reports_list = [
    'Balanço Patrimonial Ativo',
    'Balanço Patrimonial Passivo',
    'Demonstração do Resultado',
    'Demonstração do Resultado Abrangente',
    'Demonstração do Fluxo de Caixa',
    'Demonstração das Mutações do Patrimônio Líquido',
    'Demonstração de Valor Adicionado'] # Se None retorna todos os demonstrativos disponíveis.

# Filtro search_result para ITR e DFP apenas
search_result = search_result[
    (search_result['categoria']=="DFP - Demonstrações Financeiras Padronizadas") |
    (search_result['categoria']=="ITR - Informações Trimestrais")]

search_result = search_result[pd.to_numeric(search_result['numero_seq_documento'], errors='coerce').notnull()]

for index, row in search_result.iterrows():
    empresa = f"{row['cod_cvm']} - {cvm_codes[row['cod_cvm']]} - {row['numero_seq_documento']} - {row['codigo_tipo_instituicao']}"
    print("*" * 20, empresa, "*" * 20)
    
    reports = cvm_httpclient.get_report(row["numero_seq_documento"], row["codigo_tipo_instituicao"], reports_list=reports_list)
    for report in reports:
        print(report)
        reports[report]["cod_cvm"] = row["cod_cvm"]
        reports[report]["ref_date"] = row["ref_date"]
        reports[report]["numSequencia"] = row["numSequencia"]
        display(reports[report].head())
# Out:
# ******************** 021610 - BRASIL, BOLSA, BALCÃO (REGISTRO ATIVO) - 124513 - 1 ********************
# Balanço Patrimonial Ativo
#         Conta                                          Descrição       Valor  \
# 0           1                                        Ativo Total  47594773.0
# 1        1.01                                   Ativo Circulante  17129613.0
# 2     1.01.01                      Caixa e Equivalentes de Caixa   2613794.0
# 3     1.01.02                             Aplicações Financeiras  12290717.0
# 4  1.01.02.01  Aplicações Financeiras Avaliadas a Valor Justo...  11085778.0
#
#   currency_unit cod_cvm   ref_date numSequencia
# 0     Reais Mil  021610 2022-12-31       124513
# 1     Reais Mil  021610 2022-12-31       124513
# 2     Reais Mil  021610 2022-12-31       124513
# 3     Reais Mil  021610 2022-12-31       124513
# 4     Reais Mil  021610 2022-12-31       124513
# Balanço Patrimonial Passivo
# ...

# %%
reports_list = [
    'Balanço Patrimonial Ativo',
    'Balanço Patrimonial Passivo',
    'Demonstração do Resultado',
    'Demonstração do Resultado Abrangente',
    'Demonstração do Fluxo de Caixa',
    'Demonstração das Mutações do Patrimônio Líquido',
    'Demonstração de Valor Adicionado']

# %%
for index, row in search_result.iterrows():
    empresa = f"{row['cod_cvm']} - {cvm_codes[row['cod_cvm']]}"
    print("*" * 20, empresa, "*" * 20)
    reports = cvm_httpclient.get_report(row["numero_seq_documento"], row["codigo_tipo_instituicao"], reports_list=reports_list)
    
    for report in reports:
        reports[report]["cod_cvm"] = row["cod_cvm"]
        print(reports[report].head())
# Out:
# ******************** 021610 - BRASIL, BOLSA, BALCÃO (REGISTRO ATIVO) ********************
#         Conta                                          Descrição       Valor  \
# 0           1                                        Ativo Total  47594773.0
# 1        1.01                                   Ativo Circulante  17129613.0
# 2     1.01.01                      Caixa e Equivalentes de Caixa   2613794.0
# 3     1.01.02                             Aplicações Financeiras  12290717.0
# 4  1.01.02.01  Aplicações Financeiras Avaliadas a Valor Justo...  11085778.0
#
#   currency_unit cod_cvm
# 0     Reais Mil  021610
# 1     Reais Mil  021610
# 2     Reais Mil  021610
# 3     Reais Mil  021610
# 4     Reais Mil  021610
#         Conta                          Descrição       Valor currency_unit  \
# 0           2                      Passivo Total  47594773.0     Reais Mil
# 1        2.01                 Passivo Circulante   9306446.0     Reais Mil
# ...

# %% [markdown]
# 2. pybacen

# %% [markdown]
# 4. Fundamentus

# %% [markdown]
# # Intrinio

# %%
# !pip install intrinio-sdk
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 988.4/988.4 KB 24.8 MB/s eta 0:00:00
# ...

# %%
from __future__ import print_function
import time
import intrinio_sdk as intrinio
from intrinio_sdk.rest import ApiException

intrinio.ApiClient().set_api_key('OmVmMDFiYjVhMDZjYTFkYjA4NzUyMzAyNzljZDQ2Nzcy')
intrinio.ApiClient().allow_retries(True)

# %%
identifier = 'AAPL'
filed_after = ''
filed_before = ''
reported_only = False
fiscal_year = ''
statement_code = ''
type = ''
start_date = ''
end_date = ''
page_size = 100
next_page = ''

response = intrinio.CompanyApi().get_company_fundamentals(identifier, filed_after=filed_after, filed_before=filed_before, reported_only=reported_only, fiscal_year=fiscal_year, statement_code=statement_code, type=type, start_date=start_date, end_date=end_date, page_size=page_size, next_page=next_page)
print(response)
# Out:
# ---------------------------------------------------------------------------
# ApiException                              Traceback (most recent call last)
# <ipython-input-13-d8af75336997> in <module>
#      11 next_page = ''
#      12
# ---> 13 response = intrinio.CompanyApi().get_company_fundamentals(identifier, filed_after=filed_after, filed_before=filed_before, reported_only=reported_only, fiscal_year=fiscal_year, statement_code=statement_code, type=type, start_date=start_date, end_date=end_date, page_size=page_size, next_page=next_page)
#      14 print(response)
#
# /usr/local/lib/python3.9/dist-packages/intrinio_sdk/api/company_api.py in get_company_fundamentals(self, identifier, **kwargs)
#     818             return self.get_company_fundamentals_with_http_info(identifier, **kwargs)  # noqa: E501
#     819         else:
# --> 820             (data) = self.get_company_fundamentals_with_http_info(identifier, **kwargs)  # noqa: E501
#     821             return data
#     822
#
# ...

# %% [markdown]
# # **3. AlphaVantage**

# %%
# !pip install alpha_vantage
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 13.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.8/158.8 KB 14.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.2/114.2 KB 9.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 264.6/264.6 KB 18.7 MB/s eta 0:00:00
# ...

# %%
from alpha_vantage.fundamentaldata import FundamentalData

# %%
api_key ='U651A3TJS9EXCZXM'
# Define a API key para acesso aos dados
#api_key = "SUA_API_KEY_AQUI"

fd = FundamentalData(key=api_key)

# %%
# Define o ticker da ação que se deseja obter os dados
ticker = "AAPL"

# Obtém as demonstrações financeiras
financials = fd.get_income_statement_annual(symbol=ticker)

# %%
financials
# Out:
# (  fiscalDateEnding reportedCurrency   grossProfit  totalRevenue costOfRevenue  \
#  0       2022-09-30              USD  170782000000  391397000000  248640000000
#  1       2021-09-30              USD  152836000000  363172000000  234954000000
#  2       2020-09-30              USD  104956000000  271642000000  189475000000
#  3       2019-09-30              USD   98392000000  256598000000  180027000000
#  4       2018-09-30              USD  101839000000  265595000000  163756000000
#
#    costofGoodsAndServicesSold operatingIncome sellingGeneralAndAdministrative  \
#  0               223546000000    119437000000                     25094000000
#  1               212981000000    108949000000                     21973000000
#  2               169559000000     66288000000                     19916000000
#  3               161782000000     63930000000                     18245000000
#  4               163756000000     70898000000                     16705000000
#
# ...

# %%
financials[0]
# Out:
#   fiscalDateEnding reportedCurrency   grossProfit  totalRevenue costOfRevenue  \
# 0       2022-09-30              USD  170782000000  391397000000  248640000000
# 1       2021-09-30              USD  152836000000  363172000000  234954000000
# 2       2020-09-30              USD  104956000000  271642000000  189475000000
# 3       2019-09-30              USD   98392000000  256598000000  180027000000
# 4       2018-09-30              USD  101839000000  265595000000  163756000000
#
#   costofGoodsAndServicesSold operatingIncome sellingGeneralAndAdministrative  \
# 0               223546000000    119437000000                     25094000000
# 1               212981000000    108949000000                     21973000000
# 2               169559000000     66288000000                     19916000000
# 3               161782000000     63930000000                     18245000000
# 4               163756000000     70898000000                     16705000000
#
# ...

# %%
# Define o ticker da ação que se deseja obter os dados
ticker = "PETR4.SAO"

# Obtém as demonstrações financeiras
financials = fd.get_income_statement_annual(symbol=ticker)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-53-b108ff2f835d> in <module>
#       3
#       4 # Obtém as demonstrações financeiras
# ----> 5 financials = fd.get_income_statement_annual(symbol=ticker)
#
# /usr/local/lib/python3.9/dist-packages/alpha_vantage/alphavantage.py in _format_wrapper(self, *args, **kwargs)
#     216         @wraps(func)
#     217         def _format_wrapper(self, *args, **kwargs):
# --> 218             call_response, data_key, meta_data_key = func(
#     219                 self, *args, **kwargs)
#     220             if 'json' in self.output_format.lower() or 'pandas' \
#
# /usr/local/lib/python3.9/dist-packages/alpha_vantage/alphavantage.py in _call_wrapper(self, *args, **kwargs)
#     158             else:
#     159                 url = '{}{}'.format(url, apikey_parameter)
# ...

# %%
# Define o ticker da ação que se deseja obter os dados
ticker = "AMZN"

# Obtém as demonstrações financeiras
financials = fd.get_income_statement_annual(symbol=ticker)

# %%
financials[0]
# Out:
#   fiscalDateEnding reportedCurrency   grossProfit  totalRevenue costOfRevenue  \
# 0       2022-12-31              USD  139192000000  511276000000  372084000000
# 1       2021-12-31              USD  126928000000  467958000000  341030000000
# 2       2020-12-31              USD  102560000000  384452000000  281892000000
# 3       2019-12-31              USD   67626000000  278902000000  211276000000
# 4       2018-12-31              USD   65283000000  231264000000  165981000000
#
#   costofGoodsAndServicesSold operatingIncome sellingGeneralAndAdministrative  \
# 0               288831000000     12248000000                     74729000000
# 1               272344000000     24879000000                     58274000000
# 2               233307000000     22899000000                     39576000000
# 3               165536000000     14541000000                     35081000000
# 4               139156000000     12421000000                     26350000000
#
# ...

# %%
# Obtém os indicadores de valuation
metrics = fd.get_key_metrics_annual(symbol=ticker)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-47-ae8537e7d77b> in <module>
#       1 # Obtém os indicadores de valuation
# ----> 2 metrics = fd.get_key_metrics_annual(symbol=ticker)
#
# AttributeError: 'FundamentalData' object has no attribute 'get_key_metrics_annual'

# %%
metrics

# %%
# Obtém os dados de dividendos
dividends = fd.get_dividends(symbol=ticker)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-48-4cbfeb6508ec> in <module>
#       1 # Obtém os dados de dividendos
# ----> 2 dividends = fd.get_dividends(symbol=ticker)
#
# AttributeError: 'FundamentalData' object has no attribute 'get_dividends'

# %% [markdown]
# # **5. Finnhub**

# %% [markdown]
# Descrição do que é pago e do que é gratuito

# %% [markdown]
# https://finnhub.io/docs/api/financials-reported

# %%
# !pip install finnhub-python
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import finnhub

# Define a API key para acesso aos dados
finnhub_client = finnhub.Client(api_key="cgeaj8hr01qvduhgk9p0cgeaj8hr01qvduhgk9pg")

# %%
# Define o ticker da ação que se deseja obter os dados
ticker = "AAPL"

# %%
import pandas as pd

# %%
pd.DataFrame(finnhub_client.company_basic_financials('AAPL', 'all'))
# Out:
#                                    metric metricType  \
# 10DayAverageTradingVolume        72.38708   perShare
# 13WeekPriceReturnDaily           15.23307   perShare
# 26WeekPriceReturnDaily            2.85335   perShare
# 3MonthAverageTradingVolume      1448.3712   perShare
# 52WeekHigh                         179.61   perShare
# ...                                   ...        ...
# totalDebt/totalEquityAnnual      238.8104   perShare
# totalDebt/totalEquityQuarterly   195.8679   perShare
# yearToDatePriceReturnDaily       19.29501   perShare
# annual                                NaN   perShare
# quarterly                             NaN   perShare
#
#                                                                            series  \
# 10DayAverageTradingVolume                                                     NaN
# 13WeekPriceReturnDaily                                                        NaN
# ...

# %%
list(pd.DataFrame(finnhub_client.company_basic_financials('AAPL', 'all')).index)
# Out:
# ['10DayAverageTradingVolume',
#  '13WeekPriceReturnDaily',
#  '26WeekPriceReturnDaily',
#  '3MonthAverageTradingVolume',
#  '52WeekHigh',
#  '52WeekHighDate',
#  '52WeekLow',
#  '52WeekLowDate',
#  '52WeekPriceReturnDaily',
#  '5DayPriceReturnDaily',
#  'assetTurnoverAnnual',
#  'assetTurnoverTTM',
#  'beta',
#  'bookValuePerShareAnnual',
#  'bookValuePerShareQuarterly',
#  'bookValueShareGrowth5Y',
#  'capitalSpendingGrowth5Y',
#  'cashFlowPerShareAnnual',
#  'cashFlowPerShareTTM',
#  'cashPerSharePerShareAnnual',
#  'cashPerSharePerShareQuarterly',
#  'currentDividendYieldTTM',
#  'currentEv/freeCashFlowAnnual',
#  'currentEv/freeCashFlowTTM',
#  'currentRatioAnnual',
#  'currentRatioQuarterly',
#  'dividendGrowthRate5Y',
#  'dividendPerShare5Y',
#  'dividendPerShareAnnual',
#  'dividendYield5Y',
#  'dividendYieldIndicatedAnnual',
#  'dividendsPerShareTTM',
#  'ebitdPerShareTTM',
#  'ebitdaCagr5Y',
#  'ebitdaInterimCagr5Y',
#  'epsBasicExclExtraItemsAnnual',
# ...

# %%
newdata = pd.DataFrame(finnhub_client.company_basic_financials('AAPL', 'all'))

# %%
newdata.loc['revenuePerShareAnnual']
# Out:
# metric        24.15364
# metricType    perShare
# series             NaN
# symbol            AAPL
# Name: revenuePerShareAnnual, dtype: object

# %%
# Obtém as demonstrações financeiras
financials = finnhub_client.financials(ticker, statement="bs", freq = 'quarterly')
# Out:
# ---------------------------------------------------------------------------
# FinnhubAPIException                       Traceback (most recent call last)
# <ipython-input-11-3dbcc506ca22> in <module>
#       1 # Obtém as demonstrações financeiras
# ----> 2 financials = finnhub_client.financials(ticker, statement="bs", freq = 'quarterly')
#
# /usr/local/lib/python3.9/dist-packages/finnhub/client.py in financials(self, symbol, statement, freq)
#     146
#     147     def financials(self, symbol, statement, freq):
# --> 148         return self._get("/stock/financials", params={
#     149             "symbol": symbol,
#     150             "statement": statement,
#
# /usr/local/lib/python3.9/dist-packages/finnhub/client.py in _get(self, path, **kwargs)
#      69
#      70     def _get(self, path, **kwargs):
# ---> 71         return self._request("get", path, **kwargs)
#      72
#      73     @property
#
# ...

# %%
# Obtém os indicadores de valuation
metrics = finnhub_client.company_basic_financials(ticker, "all")

# %%
metrics
# Out:
# {'metric': {'10DayAverageTradingVolume': 72.38708,
#   '13WeekPriceReturnDaily': 15.23307,
#   '26WeekPriceReturnDaily': 2.85335,
#   '3MonthAverageTradingVolume': 1448.3712,
#   '52WeekHigh': 179.61,
#   '52WeekHighDate': '2022-03-30',
#   '52WeekLow': 124.18,
#   '52WeekLowDate': '2023-01-03',
#   '52WeekPriceReturnDaily': -3.49894,
#   '5DayPriceReturnDaily': 4.3771,
#   'assetTurnoverAnnual': 1.12064,
#   'assetTurnoverTTM': 1.06475,
#   'beta': 1.28223,
#   'bookValuePerShareAnnual': 3.17824,
#   'bookValuePerShareQuarterly': 3.58071,
#   'bookValueShareGrowth5Y': -13.43208,
#   'capitalSpendingGrowth5Y': -2.97116,
#   'cashFlowPerShareAnnual': 6.79335,
#   'cashFlowPerShareTTM': 6.57983,
#   'cashPerSharePerShareAnnual': 3.02971,
#   'cashPerSharePerShareQuarterly': 3.24162,
#   'currentDividendYieldTTM': 0.5871,
#   'currentEv/freeCashFlowAnnual': 29.58255,
#   'currentEv/freeCashFlowTTM': 31.43142,
#   'currentRatioAnnual': 0.87936,
#   'currentRatioQuarterly': 0.93802,
# ...

# %%
# Obtém os dados de dividendos
dividends = finnhub_client.dividends(ticker, _from="2021-01-01", to="2022-01-01")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-39-7353889ffb3f> in <module>
#       1 # Obtém os dados de dividendos
# ----> 2 dividends = finnhub_client.dividends(ticker, _from="2021-01-01", to="2022-01-01")
#
# AttributeError: 'Client' object has no attribute 'dividends'

# %%
# Imprime os resultados
print(financials)
print(metrics)
print(dividends)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-40-6ccc03769162> in <module>
#       1 # Imprime os resultados
# ----> 2 print(financials)
#       3 print(metrics)
#       4 print(dividends)
#
# NameError: name 'financials' is not defined
